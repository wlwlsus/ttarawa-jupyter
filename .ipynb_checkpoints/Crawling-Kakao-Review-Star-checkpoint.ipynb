# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\ssafy\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\ssafy\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\ssafy\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\ssafy\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\ssafy\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\ssafy\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\ssafy\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ssafy\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\ssafy\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\ssafy\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.5-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: tqdm in c:\users\ssafy\anaconda3\lib\site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: packaging in c:\users\ssafy\anaconda3\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: requests in c:\users\ssafy\anaconda3\lib\site-packages (from webdriver-manager) (2.28.1)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ssafy\anaconda3\lib\site-packages (from packaging->webdriver-manager) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ssafy\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ssafy\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ssafy\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ssafy\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: colorama in c:\users\ssafy\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.5)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-1.0.0 webdriver-manager-3.8.5

# %%
import openpyxl
import os
import sys
import time
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    return driver

filename = './data/seoul.xlsx'
spot_file = openpyxl.load_workbook(filename)
spots = spot_file.worksheets[0]



data = []

for spot in spots.iter_rows(min_row=2):
    
    name = spot[0].value
    gu = spot[1].value
    address = spot[2].value
    
    if address is not None:
        data.append([gu,name])


options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = set_chrome_driver()

arr_data = []
idx = 1
for i in data:
    print(f'{idx} / 5711 ',end=" ")
    idx += 1
    keyword = i[0] + ' ' + i[1]
    print(keyword)
    try:
        
        # 검색
        kakao_map_search_url = f"https://map.kakao.com/?q={keyword}"
        driver.get(kakao_map_search_url)
        driver.implicitly_wait(time_to_wait=10)

        newlink = driver.find_element(by='xpath',value = '//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').send_keys(Keys.ENTER)
        
        driver.switch_to.window(driver.window_handles[-1])

        res = list(driver.find_element(by='xpath',value = '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]').text.split(' ')[1].split('\n'))
        
        num_rate = res[0]
        review_cnt = res[1][1:-1]
        print(num_rate, review_cnt)
                
        arr_data.append((num_rate, review_cnt))
            
        driver.close()
        driver.switch_to.window(driver.window_handles[0]);

    except Exception as e1:
        print("정보 없음")
        print(e1)
        driver.switch_to.window(driver.window_handles[0]);
        pass

    print()

sheet = spot_file['Sheet1']
# 컬럼 추가
sheet.insert_cols(7)
sheet.insert_cols(8)
sheet.cell(row=1, column=7, value='rating') # 새로운 컬럼의 헤더 추가
sheet.cell(row=1, column=8, value='reviews') # 새로운 컬럼의 헤더 추가
    
    

# spot_file.save("./data/ExcelToCSV.xlsx")



for i, item in enumerate(arr_data, start=2): # 2번째 행부터 데이터 추가
    rate, review = item
    sheet.cell(row=i, column=7, value=rate)
    sheet.cell(row=i, column=8, value=review)
    
    
spot_file.save("./data/res_seoul.xlsx")
driver.close()
print("완료!")
# Out:
# 1 / 5711  강서구 김포국제공항국내선
# 3.8 143
#
# 2 / 5711  강남구 현대백화점압구정본점
# 3.8 52
#
# 3 / 5711  서초구 신세계백화점강남점
# 3.6 106
#
# 4 / 5711  송파구 가락동농수산물도매시장
# 5.0 1
#
# 5 / 5711  강남구 코엑스
# 3.9 65
#
# 6 / 5711  서초구 코스트코홀세일양재점
# 3.8 72
#
# 7 / 5711  강서구 롯데몰김포공항점
# 3.7 55
#
# 8 / 5711  강서구 김포국제공항
# 4.3 35
#
# 9 / 5711  영등포구 여의도한강공원
# 4.6 130
#
# 10 / 5711  중구 롯데백화점본점
# 3.5 125
#
# 11 / 5711  양천구 현대백화점목동점
# 4.0 42
#
# 12 / 5711  영등포구 코스트코홀세일양평점
# 3.2 97
#
# 13 / 5711  강남구 현대백화점무역센터점
# 3.8 66
#
# 14 / 5711  송파구 롯데월드몰
# 4.1 171
#
# 15 / 5711  영등포구 더현대서울
# 3.7 443
#
# 16 / 5711  노원구 이마트트레이더스월계점
# 0 0
#
# 17 / 5711  송파구 롯데백화점잠실점
# 2.8 61
#
# 18 / 5711  영등포구 타임스퀘어
# 4.1 149
#
# 19 / 5711  송파구 롯데월드잠실점
# 3.9 328
#
# 20 / 5711  성동구 이마트성수점
# 3.4 54
#
# 21 / 5711  용산구 HDC아이파크몰
# 2.9 117
#
# 22 / 5711  중구 신세계백화점본점신관
# 3.3 20
#
# 23 / 5711  서초구 예술의전당
# 4.3 68
#
# 24 / 5711  노원구 이마트월계점
# 3.7 103
#
# 25 / 5711  광진구 어린이대공원
# 4.2 62
#
# 26 / 5711  서초구 하나로마트양재점
# 3.8 29
#
# 27 / 5711  중구 신세계백화점본점
# 4.0 84
#
# 28 / 5711  강서구 강서농산물도매시장
# 3.7 11
#
# 29 / 5711  성동구 서울숲
# 4.6 234
#
# 30 / 5711  노원구 롯데백화점노원점
# 3.2 57
#
# 31 / 5711  송파구 올림픽공원
# 4.6 118
#
# 32 / 5711  동대문구 롯데백화점청량리점
# 3.2 22
#
# 33 / 5711  서대문구 현대백화점신촌점
# 2.9 53
#
# 34 / 5711  강서구 NC백화점강서점
# 3.0 51
#
# 35 / 5711  영등포구 IFC몰
# 3.8 101
#
# 36 / 5711  서초구 반포한강공원
# 4.4 114
#
# 37 / 5711  용산구 남산서울타워
# 4.4 179
#
# 38 / 5711  은평구 롯데몰은평점
# 3.5 54
#
# 39 / 5711  강남구 갤러리아백화점명품관EAST
# 0 0
#
# 40 / 5711  영등포구 롯데백화점영등포점
# 3.0 35
#
# 41 / 5711  용산구 국립중앙박물관
# 4.4 178
#
# 42 / 5711  성북구 현대백화점미아점
# 4.0 34
#
# 43 / 5711  영등포구 신세계백화점타임스퀘어점
# 3.9 39
#
# 44 / 5711  양천구 이마트목동점
# 2.9 38
#
# 45 / 5711  은평구 이마트은평점
# 3.8 61
#
# 46 / 5711  종로구 동대문종합시장
# 4.0 23
#
# 47 / 5711  종로구 경복궁
# 3.0 19
#
# 48 / 5711  강남구 롯데백화점강남점
# 3.2 37
#
# 49 / 5711  광진구 뚝섬한강공원
# 4.5 65
#
# 50 / 5711  강서구 이마트가양점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 51 / 5711  용산구 서울역
# 4.0 182
#
# 52 / 5711  구로구 이마트구로점
# 3.2 65
#
# 53 / 5711  중구 이마트청계천점
# 2.9 44
#
# 54 / 5711  용산구 CGV용산아이파크몰
# 3.6 129
#
# 55 / 5711  강남구 SRT수서역
# 4.2 97
#
# 56 / 5711  강서구 홈플러스강서점
# 3.7 39
#
# 57 / 5711  송파구 이마트가든파이브점
# 3.7 35
#
# 58 / 5711  종로구 북악스카이웨이
# 4.1 25
#
# 59 / 5711  송파구 가든파이브라이프
# 0 0
#
# 60 / 5711  강남구 신사동가로수길
# 3.0 459
#
# 61 / 5711  강서구 서울식물원
# 4.2 240
#
# 62 / 5711  마포구 망원한강공원
# 4.4 53
#
# 63 / 5711  도봉구 하나로마트창동점
# 3.1 32
#
# 64 / 5711  성동구 이마트왕십리점
# 3.4 47
#
# 65 / 5711  강남구 갤러리아백화점명품관WEST
# 3.9 31
#
# 66 / 5711  서초구 헌릉과인릉
# 4.0 10
#
# 67 / 5711  서초구 잠원한강공원
# 4.3 35
#
# 68 / 5711  서초구 뉴코아아울렛강남점
# 3.7 32
#
# 69 / 5711  금천구 홈플러스금천점
# 3.3 32
#
# 70 / 5711  마포구 서울월드컵경기장
# 4.2 49
#
# 71 / 5711  서초구 이마트양재점
# 3.3 26
#
# 72 / 5711  강북구 롯데백화점미아점
# 2.8 24
#
# 73 / 5711  영등포구 빅마켓영등포점
# 0 0
#
# 74 / 5711  종로구 국립현대미술관서울관
# 4.6 139
#
# 75 / 5711  마포구 망원시장
# 3.8 94
#
# 76 / 5711  용산구 이마트용산점
# 2.9 48
#
# 77 / 5711  광진구 이마트자양점
# 3.4 42
#
# 78 / 5711  종로구 광장시장
# 3.6 241
#
# 79 / 5711  관악구 롯데백화점관악점
# 2.9 34
#
# 80 / 5711  동대문구 경동시장
# 3.8 35
#
# 81 / 5711  마포구 홈플러스월드컵점
# 2.8 46
#
# 82 / 5711  영등포구 홈플러스영등포점
# 3.3 30
#
# 83 / 5711  노원구 롯데마트중계점
# 3.7 24
#
# 84 / 5711  광진구 롯데백화점건대스타시티점
# 2.8 21
#
# 85 / 5711  용산구 전쟁기념관
# 4.5 107
#
# 86 / 5711  송파구 가든파이브툴
# 3.0 2
#
# 87 / 5711  중구 두산타워
# 2.5 18
#
# 88 / 5711  은평구 NC백화점불광점
# 3.4 42
#
# 89 / 5711  종로구 팔각정북악스카이
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 90 / 5711  구로구 현대백화점디큐브시티점
# 2.9 32
#
# 91 / 5711  강남구 이마트역삼점
# 3.2 50
#
# 92 / 5711  영등포구 롯데마트양평점
# 3.6 38
#
# 93 / 5711  성동구 마장축산물시장
# 3.5 30
#
# 94 / 5711  중구 현대시티아울렛동대문점
# 3.2 61
#
# 95 / 5711  송파구 가락몰
# 2.6 10
#
# 96 / 5711  강동구 이마트명일점
# 2.6 24
#
# 97 / 5711  송파구 가든파이브웍스
# 3.0 2
#
# 98 / 5711  송파구 롯데마트제타플렉스점
# 2.3 7
#
# 99 / 5711  노원구 2001아울렛중계점
# 3.8 17
#
# 100 / 5711  양천구 홈플러스목동점
# 3.0 23
#
# 101 / 5711  송파구 롯데백화점에비뉴엘월드타워점
# 0 0
#
# 102 / 5711  중구 방산종합시장
# 3.7 3
#
# 103 / 5711  강남구 SETEC
# 2.7 20
#
# 104 / 5711  송파구 롯데월드아쿠아리움
# 3.2 50
#
# 105 / 5711  송파구 잠실야구장
# 4.4 67
#
# 106 / 5711  금천구 홈플러스시흥점
# 3.1 15
#
# 107 / 5711  종로구 북악팔각정
# 4.0 99
#
# 108 / 5711  마포구 하늘공원
# 4.4 106
#
# 109 / 5711  송파구 NC백화점송파점
# 2.1 17
#
# 110 / 5711  금천구 빅마켓금천점
# 0 0
#
# 111 / 5711  중구 밀리오레동대문점
# 0 0
#
# 112 / 5711  서초구 서울고속버스터미널경부영동선
# 4.3 6
#
# 113 / 5711  강남구 봉은사
# 3.6 83
#
# 114 / 5711  마포구 마포농수산물시장
# 2.8 21
#
# 115 / 5711  구로구 홈플러스신도림점
# 3.5 13
#
# 116 / 5711  용산구 블루스퀘어
# 2.9 37
#
# 117 / 5711  성북구 이마트하월곡점
# 3.8 20
#
# 118 / 5711  중구 롯데마트서울역점
# 3.5 43
#
# 119 / 5711  송파구 롯데마트송파점
# 3.3 20
#
# 120 / 5711  중구 국립극장
# 4.0 7
#
# 121 / 5711  마포구 이마트마포점
# 2.7 45
#
# 122 / 5711  동대문구 홈플러스동대문점
# 3.1 28
#
# 123 / 5711  성북구 홈플러스월곡점
# 2.8 28
#
# 124 / 5711  도봉구 홈플러스방학점
# 2.8 21
#
# 125 / 5711  서초구 롯데마트서초점
# 4.2 49
#
# 126 / 5711  강동구 홈플러스강동점
# 2.5 42
#
# 127 / 5711  금천구 롯데마트금천점
# 3.7 12
#
# 128 / 5711  양천구 행복한백화점
# 3.9 9
#
# 129 / 5711  구로구 고척스카이돔
# 3.9 69
#
# 130 / 5711  강서구 인서울27골프클럽
# 2.6 18
#
# 131 / 5711  서초구 세빛섬
# 3.9 66
#
# 132 / 5711  송파구 가락수산시장
# 3.2 42
#
# 133 / 5711  노원구 건영백화점
# 2.6 7
#
# 134 / 5711  송파구 홈플러스잠실점
# 2.6 15
#
# 135 / 5711  광진구 동서울종합터미널
# 2.8 75
#
# 136 / 5711  용산구 용산역
# 4.0 63
#
# 137 / 5711  양천구 목동실내아이스링크
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 138 / 5711  도봉구 이마트창동점
# 3.2 34
#
# 139 / 5711  강남구 광림아트센터BBCH홀
# 2.3 26
#
# 140 / 5711  마포구 난지한강공원
# 4.3 26
#
# 141 / 5711  강서구 롯데백화점김포공항점
# 4.0 22
#
# 142 / 5711  강서구 김포국제공항국제선
# 4.3 35
#
# 143 / 5711  중구 충무아트센터
# 3.2 27
#
# 144 / 5711  강북구 4.19기념탑
# 5.0 7
#
# 145 / 5711  강남구 아쿠아리움코엑스몰점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 146 / 5711  중구 디오트쇼핑몰
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 147 / 5711  강서구 홈플러스가양점
# 4.2 22
#
# 148 / 5711  마포구 홈플러스합정점
# 3.1 33
#
# 149 / 5711  노원구 태릉CC
# 3.8 4
#
# 150 / 5711  금천구 현대시티아울렛가산점
# 3.0 42
#
# 151 / 5711  영등포구 이마트영등포점
# 3.4 29
#
# 152 / 5711  은평구 이마트수색점
# 3.1 29
#
# 153 / 5711  금천구 마리오아울렛1관
# 3.2 32
#
# 154 / 5711  관악구 홈플러스서울남현점
# 3.6 38
#
# 155 / 5711  종로구 낙산공원
# 4.7 106
#
# 156 / 5711  금천구 W몰
# 2.8 43
#
# 157 / 5711  구로구 코스트코홀세일고척점
# 4.1 27
#
# 158 / 5711  구로구 이마트신도림점
# 3.5 24
#
# 159 / 5711  송파구 현대시티몰가든파이브점
# 3.2 13
#
# 160 / 5711  마포구 평화의공원
# 4.2 18
#
# 161 / 5711  동작구 성대전통시장
# 4.5 10
#
# 162 / 5711  종로구 광화문
# 4.7 92
#
# 163 / 5711  종로구 조계사
# 4.0 56
#
# 164 / 5711  중구 제일평화시장
# 2.1 9
#
# 165 / 5711  성북구 이마트미아점
# 3.2 27
#
# 166 / 5711  용산구 이촌한강공원
# 4.3 38
#
# 167 / 5711  금천구 독산동우시장
# 1.0 1
#
# 168 / 5711  서대문구 서대문자연사박물관
# 4.1 30
#
# 169 / 5711  은평구 진관사
# 4.3 23
#
# 170 / 5711  송파구 샤롯데씨어터
# 2.4 42
#
# 171 / 5711  강북구 수유시장
# 3.4 28
#
# 172 / 5711  용산구 용산가족공원
# 4.5 55
#
# 173 / 5711  영등포구 선유도공원
# 4.4 92
#
# 174 / 5711  은평구 북한산성
# 5.0 3
#
# 175 / 5711  노원구 세이브존노원점
# 3.1 14
#
# 176 / 5711  영등포구 이마트여의도점
# 4.0 22
#
# 177 / 5711  영등포구 대신시장
# 5.0 1
#
# 178 / 5711  중구 롯데백화점에비뉴엘본점
# 2.6 13
#
# 179 / 5711  양천구 이마트신월점
# 3.8 24
#
# 180 / 5711  송파구 롯데콘서트홀
# 3.6 18
#
# 181 / 5711  구로구 NC백화점신구로점
# 3.4 41
#
# 182 / 5711  도봉구 신창시장
# 3.7 3
#
# 183 / 5711  중구 누죤
# 3.0 4
#
# 184 / 5711  금천구 마리오아울렛3관
# 3.6 22
#
# 185 / 5711  성동구 금남시장
# 4.6 7
#
# 186 / 5711  강동구 이마트천호점
# 2.8 42
#
# 187 / 5711  송파구 롯데시네마월드타워
# 3.5 71
#
# 188 / 5711  성북구 길상사
# 4.3 40
#
# 189 / 5711  동대문구 청량리청과물시장
# 4.0 6
#
# 190 / 5711  중구 ddp패션몰
# 4.3 7
#
# 191 / 5711  강북구 도선사
# 3.9 14
#
# 192 / 5711  종로구 창경궁
# 4.8 97
#
# 193 / 5711  강동구 2001아울렛천호점
# 3.4 9
#
# 194 / 5711  송파구 키자니아서울점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 195 / 5711  강남구 도산공원
# 4.6 30
#
# 196 / 5711  서초구 한가람미술관
# 3.1 31
#
# 197 / 5711  강서구 국립항공박물관
# 4.4 32
#
# 198 / 5711  성동구 CGV왕십리
# 2.9 34
#
# 199 / 5711  양천구 대한민국예술인센터
# 4.5 2
#
# 200 / 5711  성북구 고려대아이스링크
# 3.3 6
#
# 201 / 5711  강동구 광나루한강공원
# 1.0 1
#
# 202 / 5711  마포구 KT&G상상마당홍대
# 2.4 10
#
# 203 / 5711  강남구 더라움
# 5.0 1
#
# 204 / 5711  영등포구 여의도백화점
# 0 0
#
# 205 / 5711  성동구 메가박스성수
# 3.6 32
#
# 206 / 5711  송파구 방이시장
# 3.7 3
#
# 207 / 5711  노원구 홈플러스중계점
# 3.3 20
#
# 208 / 5711  강서구 롯데마트김포공항점
# 3.7 17
#
# 209 / 5711  강북구 롯데마트삼양점
# 3.8 17
#
# 210 / 5711  구로구 푸른수목원
# 4.4 56
#
# 211 / 5711  용산구 후암시장
# 4.0 5
#
# 212 / 5711  강남구 이마트수서점
# 2.4 23
#
# 213 / 5711  도봉구 방학동도깨비시장
# 2.0 5
#
# 214 / 5711  동대문구 롯데마트청량리점
# 3.7 16
#
# 215 / 5711  서대문구 서대문형무소역사관
# 4.7 46
#
# 216 / 5711  서초구 신세계센트럴시티터미널호남선
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 217 / 5711  송파구 송파책박물관
# 3.5 26
#
# 218 / 5711  영등포구 양화한강공원
# 4.3 15
#
# 219 / 5711  영등포구 여의도백화점
# 0 0
#
# 220 / 5711  용산구 노들섬
# 4.6 84
#
# 221 / 5711  용산구 리움미술관
# 4.3 87
#
# 222 / 5711  강남구 CGV강남
# 3.2 44
#
# 223 / 5711  중구 대한극장
# 3.5 33
#
# 224 / 5711  중구 롯데영플라자명동점
# 4.1 15
#
# 225 / 5711  광진구 커먼그라운드
# 3.3 47
#
# 226 / 5711  종로구 서울역사박물관
# 4.3 42
#
# 227 / 5711  광진구 롯데시네마건대입구
# 3.1 27
#
# 228 / 5711  은평구 롯데마트은평점
# 3.7 22
#
# 229 / 5711  강남구 CGV청담씨네시티
# 3.0 27
#
# 230 / 5711  중구 남산공원
# 4.5 43
#
# 231 / 5711  마포구 망원유수지체육공원
# 0 0
#
# 232 / 5711  서초구 예술의전당오페라하우스
# 3.8 8
#
# 233 / 5711  강동구 천호공원
# 4.2 13
#
# 234 / 5711  강동구 서울암사동유적
# 4.8 9
#
# 235 / 5711  관악구 현대시장
# 4.0 2
#
# 236 / 5711  강남구 메가박스코엑스
# 4.0 69
#
# 237 / 5711  중구 신라면세점서울점
# 2.8 12
#
# 238 / 5711  송파구 마천중앙시장
# 3.9 13
#
# 239 / 5711  마포구 다농마트
# 3.1 15
#
# 240 / 5711  성북구 정릉시장
# 4.7 11
#
# 241 / 5711  영등포구 영등포청과시장
# 5.0 2
#
# 242 / 5711  관악구 타임스트림
# 4.8 14
#
# 243 / 5711  동작구 이마트이수점
# 2.7 35
#
# 244 / 5711  서초구 예술의전당콘서트홀
# 4.3 3
#
# 245 / 5711  서초구 국립국악원예악당
# 0 0
#
# 246 / 5711  중구 청평화시장
# 5.0 3
#
# 247 / 5711  용산구 롯데시네마용산
# 3.2 25
#
# 248 / 5711  은평구 대림시장
# 3.6 15
#
# 249 / 5711  구로구 가리봉시장
# 3.7 6
#
# 250 / 5711  은평구 서울혁신파크
# 3.6 10
#
# 251 / 5711  강북구 화계사
# 4.3 18
#
# 252 / 5711  강동구 롯데시네마강동
# 2.6 17
#
# 253 / 5711  중구 중부시장
# 3.6 10
#
# 254 / 5711  강서구 화곡본동시장
# 2.8 5
#
# 255 / 5711  강서구 롯데시네마김포공항
# 3.4 25
#
# 256 / 5711  중구 명보아트홀
# 0 0
#
# 257 / 5711  용산구 국립한글박물관
# 4.1 18
#
# 258 / 5711  송파구 우리금융아트홀
# 5.0 1
#
# 259 / 5711  서대문구 현대백화점 유플렉스신촌점
# 4.2 13
#
# 260 / 5711  서초구 서울남부터미널
# 2.3 47
#
# 261 / 5711  용산구 용문시장
# 3.5 10
#
# 262 / 5711  마포구 AK&홍대점
# 4.0 21
#
# 263 / 5711  구로구 2001아울렛구로점
# 3.9 8
#
# 264 / 5711  중구 서울시립미술관
# 3.2 77
#
# 265 / 5711  강동구 암사종합시장
# 3.8 9
#
# 266 / 5711  송파구 서울스카이
# 3.6 57
#
# 267 / 5711  마포구 메가박스상암월드컵경기장
# 2.3 21
#
# 268 / 5711  송파구 엄마손쇼핑센터
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 269 / 5711  영등포구 CGV영등포
# 3.4 40
#
# 270 / 5711  강남구 CGV압구정본관
# 2.9 15
#
# 271 / 5711  중구 서울중앙시장
# 3.5 11
#
# 272 / 5711  송파구 석촌호수동호
# 4.1 38
#
# 273 / 5711  동작구 보라매공원
# 4.4 75
#
# 274 / 5711  송파구 CGV송파
# 3.6 31
#
# 275 / 5711  중구 SFC몰
# 5.0 2
#
# 276 / 5711  송파구 올림픽홀
# 3.5 6
#
# 277 / 5711  강서구 강서한강공원
# 3.0 8
#
# 278 / 5711  송파구 문정동로데오거리
# 3.7 6
#
# 279 / 5711  광진구 어린이회관
# 0 0
#
# 280 / 5711  광진구 CGV건대입구
# 2.8 21
#
# 281 / 5711  광진구 롯데마트강변점
# 2.4 15
#
# 282 / 5711  중구 황학동주방기구거리
# 3.8 4
#
# 283 / 5711  강서구 롯데시네마가양
# 3.5 18
#
# 284 / 5711  강서구 CGV등촌
# 3.3 15
#
# 285 / 5711  종로구 CGV피카디리1958
# 2.7 23
#
# 286 / 5711  영등포구 아쿠아플라넷63
# 3.1 25
#
# 287 / 5711  강서구 볏골공원
# 5.0 3
#
# 288 / 5711  마포구 월드컵공원
# 4.0 12
#
# 289 / 5711  서초구 양재시민의숲
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 290 / 5711  중구 손기정체육공원
# 4.8 4
#
# 291 / 5711  구로구 구로시장
# 2.8 5
#
# 292 / 5711  광진구 스타시티
# 3.7 27
#
# 293 / 5711  종로구 대학로
# 4.0 7
#
# 294 / 5711  종로구 청와대사랑채
# 3.5 99
#
# 295 / 5711  관악구 봉일시장
# 0 0
#
# 296 / 5711  마포구 난지천공원
# 3.5 6
#
# 297 / 5711  노원구 불암산스포츠타운
# 0 0
#
# 298 / 5711  영등포구 썬프라자
# 4.2 5
#
# 299 / 5711  강서구 메가박스화곡
# 3.6 20
#
# 300 / 5711  영등포구 문래근린공원
# 4.5 2
#
# 301 / 5711  송파구 한성백제박물관
# 3.4 14
#
# 302 / 5711  종로구 청와대
# 3.7 214
#
# 303 / 5711  강서구 KBS아레나
# 3.2 5
#
# 304 / 5711  강남구 압구정로데오거리
# 4.3 17
#
# 305 / 5711  성동구 비트플렉스
# 0 0
#
# 306 / 5711  중구 신평화패션타운
# 5.0 2
#
# 307 / 5711  종로구 북촌한옥마을
# 4.0 68
#
# 308 / 5711  노원구 광운대학교아이스링크
# 4.8 5
#
# 309 / 5711  영등포구 영등포공원
# 3.1 8
#
# 310 / 5711  마포구 와이즈파크
# 2.3 3
#
# 311 / 5711  강남구 금강쇼핑센터
# 0 0
#
# 312 / 5711  종로구 동화면세점본점
# 0 0
#
# 313 / 5711  중구 덕수궁
# 4.8 154
#
# 314 / 5711  강남구 KT&G상상마당대치아트홀
# 3.4 32
#
# 315 / 5711  동작구 남성사계시장
# 3.5 13
#
# 316 / 5711  송파구 올림픽프라자
# 1.0 3
#
# 317 / 5711  동대문구 서울풍물시장
# 4.1 27
#
# 318 / 5711  노원구 불암산나비정원
# 4.8 5
#
# 319 / 5711  중구 조선일보미술관
# 1.0 1
#
# 320 / 5711  마포구 노을공원
# 4.1 21
#
# 321 / 5711  구로구 CGV구로
# 3.0 20
#
# 322 / 5711  강남구 세븐럭코엑스센터점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 323 / 5711  강남구 선정릉
# 4.4 39
#
# 324 / 5711  영등포구 이랜드크루즈여의도선착장
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 325 / 5711  중구 에이피엠플레이스
# 3.0 6
#
# 326 / 5711  노원구 공릉동도깨비시장
# 3.5 13
#
# 327 / 5711  서초구 매헌윤봉길의사기념관
# 4.9 17
#
# 328 / 5711  노원구 동천실내스케이트장
# 3.0 2
#
# 329 / 5711  광진구 중곡제일시장
# 0 0
#
# 330 / 5711  용산구 아이파크몰
# 2.9 117
#
# 331 / 5711  관악구 우림시장
# 5.0 1
#
# 332 / 5711  광진구 영화사
# 4.1 7
#
# 333 / 5711  관악구 관악신사시장
# 3.0 2
#
# 334 / 5711  영등포구 롯데시네마영등포
# 2.6 17
#
# 335 / 5711  성동구 롯데마트행당역점
# 3.4 16
#
# 336 / 5711  영등포구 서울마리나클럽앤요트
# 4.1 8
#
# 337 / 5711  강서구 메가박스마곡
# 3.3 14
#
# 338 / 5711  서대문구 CGV신촌아트레온
# 3.2 30
#
# 339 / 5711  마포구 하나로마트신촌점
# 4.0 10
#
# 340 / 5711  양천구 파리공원
# 3.8 17
#
# 341 / 5711  강북구 솔밭공원
# 4.3 9
#
# 342 / 5711  구로구 지밸리몰
# 5.0 1
#
# 343 / 5711  용산구 효창공원
# 4.1 26
#
# 344 / 5711  강동구 주양쇼핑
# 0 0
#
# 345 / 5711  중구 맥스타일
# 5.0 2
#
# 346 / 5711  강북구 롯데시네마수유
# 2.2 19
#
# 347 / 5711  성북구 개운사
# 2.3 7
#
# 348 / 5711  종로구 안녕인사동
# 4.1 50
#
# 349 / 5711  중구 밀리오레명동점
# 1.0 1
#
# 350 / 5711  서초구 반포종합운동장
# 4.0 7
#
# 351 / 5711  구로구 디큐브아트센터
# 3.6 13
#
# 352 / 5711  송파구 메가박스송파파크하비오
# 3.1 22
#
# 353 / 5711  중구 남산케이블카
# 3.0 53
#
# 354 / 5711  서초구 양곡도매시장
# 0 0
#
# 355 / 5711  동작구 태평백화점폐점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 356 / 5711  종로구 창덕궁
# 4.8 99
#
# 357 / 5711  마포구 절두산순교성지
# 4.2 22
#
# 358 / 5711  관악구 르네상스쇼핑몰
# 2.3 3
#
# 359 / 5711  노원구 화랑대철도공원
# 4.6 5
#
# 360 / 5711  성동구 에스팩토리
# 2.6 7
#
# 361 / 5711  중구 롯데면세점본점
# 5.0 1
#
# 362 / 5711  강동구 CGV천호
# 2.7 39
#
# 363 / 5711  마포구 문화비축기지
# 4.1 40
#
# 364 / 5711  금천구 별빛남문시장
# 4.0 5
#
# 365 / 5711  관악구 관악프라자
# 0 0
#
# 366 / 5711  종로구 총회창립100주년기념관
# 5.0 1
#
# 367 / 5711  종로구 두산아트센터
# 3.6 8
#
# 368 / 5711  용산구 하나로마트용산점
# 3.3 9
#
# 369 / 5711  관악구 낙성대공원
# 4.6 28
#
# 370 / 5711  양천구 목동야구장
# 4.2 5
#
# 371 / 5711  송파구 석촌호수동호
# 4.1 38
#
# 372 / 5711  서대문구 봉원사
# 3.8 5
#
# 373 / 5711  성북구 삼청각
# 2.3 3
#
# 374 / 5711  용산구 백범김구기념관
# 4.3 23
#
# 375 / 5711  강서구 방신재래시장
# 2.8 9
#
# 376 / 5711  양천구 신곡종합시장
# 0 0
#
# 377 / 5711  양천구 양천해누리체육공원
# 0 0
#
# 378 / 5711  강동구 강동아트센터
# 5.0 5
#
# 379 / 5711  서초구 구룡사
# 3.0 2
#
# 380 / 5711  영등포구 CGV여의도
# 3.6 29
#
# 381 / 5711  금천구 호압사
# 4.5 13
#
# 382 / 5711  강남구 백암아트홀
# 4.0 3
#
# 383 / 5711  종로구 국립어린이과학관
# 3.7 12
#
# 384 / 5711  중구 서소문성지역사박물관
# 4.5 45
#
# 385 / 5711  중구 눈스퀘어
# 4.1 9
#
# 386 / 5711  중구 평화시장
# 4.5 4
#
# 387 / 5711  동대문구 서울경동약령시장
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 388 / 5711  양천구 서서울호수공원
# 4.7 44
#
# 389 / 5711  강북구 우이동유원지
# 0 0
#
# 390 / 5711  도봉구 둘리뮤지엄
# 3.0 12
#
# 391 / 5711  서초구 반포쇼핑타운
# 0 0
#
# 392 / 5711  강남구 능인선원포이동법당
# 3.6 5
#
# 393 / 5711  중구 안중근의사기념관
# 4.4 33
#
# 394 / 5711  구로구 구로리공원
# 1.7 3
#
# 395 / 5711  강북구 CGV수유
# 2.7 21
#
# 396 / 5711  노원구 서울시립북서울미술관
# 4.1 13
#
# 397 / 5711  중구 남산골한옥마을
# 4.1 36
#
# 398 / 5711  송파구 소마미술관
# 3.7 18
#
# 399 / 5711  종로구 가나아트센터
# 4.2 11
#
# 400 / 5711  동작구 메가박스이수
# 2.9 22
#
# 401 / 5711  노원구 서울생활사박물관
# 4.5 11
#
# 402 / 5711  강남구 마이아트뮤지엄
# 2.7 38
#
# 403 / 5711  강서구 허준박물관
# 4.5 4
#
# 404 / 5711  마포구 서울함공원
# 4.0 17
#
# 405 / 5711  영등포구 대림중앙시장
# 2.9 19
#
# 406 / 5711  도봉구 다락원체육공원
# 4.6 7
#
# 407 / 5711  은평구 응암시장
# 3.6 15
#
# 408 / 5711  동대문구 롯데시네마청량리
# 2.1 29
#
# 409 / 5711  구로구 리치몰
# 5.0 1
#
# 410 / 5711  서대문구 포방터시장
# 1.3 91
#
# 411 / 5711  관악구 롯데시네마서울대입구
# 2.6 24
#
# 412 / 5711  종로구 서울미술관
# 4.0 41
#
# 413 / 5711  노원구 와우쇼핑몰
# 0 0
#
# 414 / 5711  중구 동대문역사문화공원
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 415 / 5711  금천구 CT LEX
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 416 / 5711  영등포구 영산아트홀
# 1.3 3
#
# 417 / 5711  광진구 예스24라이브홀
# 3.7 9
#
# 418 / 5711  중구 HelloAPM
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 419 / 5711  은평구 볼베어파크은평점
# 3.1 15
#
# 420 / 5711  용산구 남산야외식물원
# 4.2 19
#
# 421 / 5711  강북구 북한산국립공원백운대탐방지원센터
# 5.0 4
#
# 422 / 5711  송파구 롯데마트월드타워점
# 3.8 20
#
# 423 / 5711  양천구 메가박스목동
# 3.9 18
#
# 424 / 5711  광진구 CGV강변
# 3.0 30
#
# 425 / 5711  송파구 송파나루공원서호
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 426 / 5711  종로구 통인시장
# 2.5 60
#
# 427 / 5711  마포구 롯데시네마홍대입구
# 2.5 21
#
# 428 / 5711  성동구 소월아트홀
# 0 0
#
# 429 / 5711  서대문구 독립문
# 4.7 30
#
# 430 / 5711  금천구 롯데팩토리아울렛가산점
# 2.3 17
#
# 431 / 5711  서초구 예술의전당음악당
# 0 0
#
# 432 / 5711  서대문구 서대문독립공원
# 4.8 15
#
# 433 / 5711  은평구 수색역
# 3.4 9
#
# 434 / 5711  종로구 국립민속박물관
# 2.5 33
#
# 435 / 5711  송파구 문정동로데오거리
# 3.7 6
#
# 436 / 5711  송파구 파크하비오워터킹덤
# 2.2 19
#
# 437 / 5711  노원구 마들스포츠타운
# 5.0 2
#
# 438 / 5711  성북구 보문사
# 4.0 6
#
# 439 / 5711  관악구 신원시장
# 2.6 14
#
# 440 / 5711  송파구 새마을시장
# 4.6 5
#
# 441 / 5711  도봉구 서울창포원
# 4.1 14
#
# 442 / 5711  종로구 청와대정문
# 4.2 5
#
# 443 / 5711  구로구 개봉중앙시장
# 1.0 1
#
# 444 / 5711  서대문구 메가박스신촌
# 3.7 27
#
# 445 / 5711  종로구 마로니에공원
# 4.6 20
#
# 446 / 5711  강서구 LG아트센터서울
# 3.8 32
#
# 447 / 5711  강남구 LG아트센터
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 448 / 5711  종로구 국립고궁박물관
# 4.6 29
#
# 449 / 5711  성북구 CGV성신여대입구
# 3.5 17
#
# 450 / 5711  송파구 래미안갤러리
# 5.0 2
#
# 451 / 5711  은평구 삼천사
# 5.0 1
#
# 452 / 5711  강동구 길동복조리시장
# 3.7 12
#
# 453 / 5711  송파구 천마풋살파크
# 2.8 5
#
# 454 / 5711  강남구 신한아트홀
# 5.0 2
#
# 455 / 5711  강남구 라움아트센터
# 5.0 1
#
# 456 / 5711  강북구 CGV미아
# 2.7 14
#
# 457 / 5711  중구 동화상가
# 0 0
#
# 458 / 5711  노원구 CGV중계
# 2.2 12
#
# 459 / 5711  종로구 동묘시장
# 3.1 53
#
# 460 / 5711  서초구 관문사
# 4.0 4
#
# 461 / 5711  양천구 목동깨비시장
# 3.0 6
#
# 462 / 5711  강동구 호원아트홀
# 0 0
#
# 463 / 5711  송파구 롯데면세점월드타워점
# 3.7 3
#
# 464 / 5711  양천구 신영시장
# 2.6 11
#
# 465 / 5711  은평구 북한산국립공원북한산성탐방지원센터
# 5.0 2
#
# 466 / 5711  중구 숭례문
# 4.6 41
#
# 467 / 5711  종로구 서울극장폐점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 468 / 5711  종로구 상명아트센터
# 0 0
#
# 469 / 5711  송파구 롯데월드아이스링크
# 1.9 17
#
# 470 / 5711  마포구 롯데시네마합정
# 3.6 12
#
# 471 / 5711  송파구 송파나루공원동호
# 2.0 3
#
# 472 / 5711  마포구 소극장산울림
# 4.3 3
#
# 473 / 5711  금천구 퐁퐁플라워가산센터
# 4.0 11
#
# 474 / 5711  강남구 광림아트센터장천홀
# 3.6 5
#
# 475 / 5711  마포구 난지천공원인조잔디축구장
# 0 0
#
# 476 / 5711  양천구 로운아뜨리움
# 0 0
#
# 477 / 5711  마포구 신한pLay스퀘어
# 1.0 1
#
# 478 / 5711  양천구 CGV목동
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 479 / 5711  광진구 아차산배수지체육공원
# 0 0
#
# 480 / 5711  금천구 롯데시네마가산디지털
# 3.2 9
#
# 481 / 5711  중구 호암아트홀
# 0 0
#
# 482 / 5711  서초구 메가박스강남
# 2.3 38
#
# 483 / 5711  서대문구 금호아트홀연세
# 3.0 4
#
# 484 / 5711  용산구 국립중앙박물관어린이박물관
# 5.0 5
#
# 485 / 5711  강동구 길동자연생태공원
# 3.6 11
#
# 486 / 5711  노원구 상계중앙시장
# 5.0 1
#
# 487 / 5711  양천구 경창시장
# 2.7 3
#
# 488 / 5711  노원구 태릉
# 3.2 10
#
# 489 / 5711  동대문구 간데메공원
# 4.5 4
#
# 490 / 5711  강남구 바운스트램폴린파크삼성센터
# 3.4 10
#
# 491 / 5711  노원구 서울시립과학관
# 4.4 15
#
# 492 / 5711  노원구 마들스포츠타운
# 5.0 2
#
# 493 / 5711  송파구 잠실어울림축구장
# 3.0 5
#
# 494 / 5711  노원구 태릉국제스케이트장
# 2.7 7
#
# 495 / 5711  용산구 롯데아울렛서울역점
# 2.8 15
#
# 496 / 5711  영등포구 당산공원
# 2.5 2
#
# 497 / 5711  금천구 금빛공원
# 4.3 7
#
# 498 / 5711  양천구 현대백화점 유플렉스목동점
# 4.0 42
#
# 499 / 5711  광진구 구의야구공원
# 0 0
#
# 500 / 5711  금천구 마리오아울렛2관
# 3.0 9
#
# 501 / 5711  강남구 한국도심공항
# 5.0 1
#
# 502 / 5711  동대문구 서울한방진흥센터
# 5.0 5
#
# 503 / 5711  광진구 신성종합시장
# 0 0
#
# 504 / 5711  강남구 윤당아트홀
# 3.0 2
#
# 505 / 5711  종로구 동대문문구완구종합시장
# 4.2 21
#
# 506 / 5711  강남구 서울옥션강남센터
# 5.0 3
#
# 507 / 5711  강동구 둔촌역전통시장
# 2.3 3
#
# 508 / 5711  영등포구 대림어린이공원
# 0 0
#
# 509 / 5711  은평구 CGV불광
# 2.0 33
#
# 510 / 5711  중구 혜양엘리시움
# 0 0
#
# 511 / 5711  서초구 라시따델라모다
# 4.0 2
#
# 512 / 5711  중구 화폐박물관
# 4.0 20
#
# 513 / 5711  종로구 흥인지문
# 4.9 33
#
# 514 / 5711  강서구 송화벽화시장
# 4.8 8
#
# 515 / 5711  중구 서소문역사공원
# 4.8 16
#
# 516 / 5711  노원구 롯데시네마노원
# 2.0 34
#
# 517 / 5711  종로구 국제갤러리
# 3.1 29
#
# 518 / 5711  송파구 롯데월드어드벤쳐
# 3.1 21
#
# 519 / 5711  강북구 우이시장
# 0 0
#
# 520 / 5711  광진구 우리유황온천
# 3.5 15
#
# 521 / 5711  은평구 수국사
# 3.8 4
#
# 522 / 5711  강서구 남부시장
# 4.1 8
#
# 523 / 5711  강남구 메종에르메스
# 3.0 9
#
# 524 / 5711  종로구 대학로예술극장
# 0 0
#
# 525 / 5711  강남구 스타필드코엑스몰
# 3.6 30
#
# 526 / 5711  영등포구 영등포아트홀
# 3.7 3
#
# 527 / 5711  중구 국립정동극장
# 4.3 10
#
# 528 / 5711  금천구 롯데시네마독산
# 3.3 11
#
# 529 / 5711  영등포구 63스퀘어
# 4.5 58
#
# 530 / 5711  강남구 역삼청소년수련관
# 3.2 6
#
# 531 / 5711  강북구 삼양시장
# 0 0
#
# 532 / 5711  중구 삼익패션타운
# 5.0 1
#
# 533 / 5711  영등포구 영등포역
# 3.5 31
#
# 534 / 5711  강남구 롯데시네마도곡
# 3.0 31
#
# 535 / 5711  관악구 삼성동시장
# 2.8 5
#
# 536 / 5711  종로구 화정박물관
# 4.0 2
#
# 537 / 5711  강동구 메가박스강동
# 2.8 13
#
# 538 / 5711  서초구 한강시민공원잠원지구수영장
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 539 / 5711  송파구 서울방이동고분군
# 4.5 2
#
# 540 / 5711  종로구 대한민국역사박물관
# 4.3 47
#
# 541 / 5711  노원구 초안산인조잔디축구장
# 0 0
#
# 542 / 5711  영등포구 안양천영롱이갈대야구장
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 543 / 5711  용산구 신동아쇼핑센터
# 0 0
#
# 544 / 5711  종로구 아르코예술극장
# 4.0 5
#
# 545 / 5711  양천구 생명과학박물관
# 5.0 1
#
# 546 / 5711  관악구 서울특별시교육청과학전시관본관
# 0 0
#
# 547 / 5711  송파구 송파구여성축구장
# 3.7 3
#
# 548 / 5711  종로구 탑골공원
# 2.8 26
#
# 549 / 5711  용산구 노들섬라이브하우스
# 3.0 33
#
# 550 / 5711  중구 메가박스동대문
# 2.7 27
#
# 551 / 5711  영등포구 이랜드크루즈양화선착장
# 0 0
#
# 552 / 5711  종로구 CGV대학로
# 2.9 27
#
# 553 / 5711  관악구 롯데시네마신림
# 2.5 27
#
# 554 / 5711  강남구 CGV압구정신관
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 555 / 5711  광진구 메가박스군자
# 2.9 18
#
# 556 / 5711  동작구 스페이스살림
# 3.0 7
#
# 557 / 5711  영등포구 안양천생태공원
# 4.0 1
#
# 558 / 5711  서초구 무지개쇼핑센터
# 0 0
#
# 559 / 5711  성북구 의릉
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 560 / 5711  동대문구 현대시장
# 1.0 1
#
# 561 / 5711  중구 신세계면세점명동점
# 3.5 4
#
# 562 / 5711  양천구 안양천야구장
# 0 0
#
# 563 / 5711  용산구 N서울타워
# 3.9 42
#
# 564 / 5711  강서구 약사사
# 3.9 7
#
# 565 / 5711  영등포구 여의도공원
# 4.3 61
#
# 566 / 5711  구로구 남구로시장
# 4.5 4
#
# 567 / 5711  서초구 뉴코아아울렛강남점패션관
# 3.7 32
#
# 568 / 5711  성북구 흥천사
# 3.7 3
#
# 569 / 5711  강동구 암사선사유적박물관
# 5.0 1
#
# 570 / 5711  양천구 신트리공원
# 4.5 2
#
# 571 / 5711  강남구 코엑스아티움
# 2.6 7
#
# 572 / 5711  강동구 고분다리전통시장
# 3.0 2
#
# 573 / 5711  강서구 방화근린공원
# 4.3 6
#
# 574 / 5711  강남구 선릉
# 4.4 39
#
# 575 / 5711  송파구 이랜드크루즈잠실선착장
# 1.0 1
#
# 576 / 5711  송파구 잠실유람선터미널
# 3.0 3
#
# 577 / 5711  서초구 양재천근린공원
# 5.0 4
#
# 578 / 5711  송파구 서울청과
# 0 0
#
# 579 / 5711  은평구 롯데시네마은평
# 2.7 23
#
# 580 / 5711  강남구 캘리클럽청담점
# 2.0 4
#
# 581 / 5711  중구 디자이너클럽
# 5.0 1
#
# 582 / 5711  영등포구 렛츠런CCC영등포지점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 583 / 5711  강남구 롯데시네마브로드웨이
# 1.8 66
#
# 584 / 5711  송파구 오금공원
# 4.0 6
#
# 585 / 5711  성동구 응봉산암벽공원
# 0 0
#
# 586 / 5711  성동구 서울새활용플라자
# 0 0
#
# 587 / 5711  용산구 한강쇼핑센터
# 5.0 1
#
# 588 / 5711  송파구 서울놀이마당
# 0 0
#
# 589 / 5711  은평구 연서시장
# 2.8 10
#
# 590 / 5711  송파구 뽀로로파크잠실롯데월드점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 591 / 5711  송파구 불광사
# 0 0
#
# 592 / 5711  강남구 식물관PH
# 3.2 46
#
# 593 / 5711  종로구 석파정
# 4.7 76
#
# 594 / 5711  강남구 은곡마을공원
# 0 0
#
# 595 / 5711  강남구 현대모터스튜디오서울
# 4.8 19
#
# 596 / 5711  관악구 남태령고개
# 5.0 2
#
# 597 / 5711  양천구 목사랑시장
# 3.3 3
#
# 598 / 5711  성동구 성수아트홀
# 4.0 2
#
# 599 / 5711  영등포구 aza쇼핑몰
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 600 / 5711  용산구 만리동시장
# 2.8 4
#
# 601 / 5711  종로구 경찰박물관
# 4.3 6
#
# 602 / 5711  광진구 퐁퐁플라워건대센터
# 4.3 11
#
# 603 / 5711  구로구 롯데시네마신도림
# 3.1 16
#
# 604 / 5711  종로구 동대문종합시장A동
# 3.0 1
#
# 605 / 5711  송파구 마천청소년수련관
# 0 0
#
# 606 / 5711  종로구 사직공원
# 4.2 6
#
# 607 / 5711  노원구 CGV하계
# 3.5 8
#
# 608 / 5711  광진구 어린이회관눈썰매장
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 609 / 5711  강동구 나비쇼핑몰
# 3.0 4
#
# 610 / 5711  마포구 CGV홍대
# 2.2 25
#
# 611 / 5711  강남구 SAC아트홀
# 3.0 1
#
# 612 / 5711  종로구 윤동주문학관
# 4.3 30
#
# 613 / 5711  송파구 한국청과
# 0 0
#
# 614 / 5711  강남구 현대백화점면세점무역센터점
# 3.3 7
#
# 615 / 5711  강남구 파르나스몰
# 3.5 4
#
# 616 / 5711  송파구 천마공원축구장
# 0 0
#
# 617 / 5711  동대문구 불로장생타워
# 5.0 1
#
# 618 / 5711  강남구 메가박스강남대로
# 3.6 23
#
# 619 / 5711  성동구 성수연방
# 3.4 37
#
# 620 / 5711  동작구 달마사
# 4.2 11
#
# 621 / 5711  강남구 한국문화의집
# 5.0 1
#
# 622 / 5711  마포구 이마트신촌점
# 3.0 55
#
# 623 / 5711  중구 CGV동대문
# 2.8 17
#
# 624 / 5711  성동구 살곶이체육공원
# 3.0 3
#
# 625 / 5711  서초구 예술의전당CJ토월극장
# 4.0 2
#
# 626 / 5711  노원구 삼부프라자
# 3.0 2
#
# 627 / 5711  종로구 예스24스테이지
# 2.8 4
#
# 628 / 5711  강남구 청담도로공원
# 3.3 3
#
# 629 / 5711  중구 아트프라자
# 3.0 1
#
# 630 / 5711  용산구 신라아이파크면세점용산점
# 0 0
#
# 631 / 5711  성동구 서울숲씨어터
# 0 0
#
# 632 / 5711  강남구 대치유수지체육공원
# 0 0
#
# 633 / 5711  동대문구 청량리역
# 3.7 57
#
# 634 / 5711  강남구 기아360
# 4.3 3
#
# 635 / 5711  용산구 국립중앙박물관극장용
# 5.0 1
#
# 636 / 5711  동작구 동작주차공원
# 5.0 1
#
# 637 / 5711  중구 메사
# 3.8 4
#
# 638 / 5711  성북구 아리랑시네센터
# 5.0 5
#
# 639 / 5711  종로구 씨네큐브광화문점
# 4.2 38
#
# 640 / 5711  종로구 환기미술관
# 4.1 29
#
# 641 / 5711  송파구 석촌고분공원
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 642 / 5711  강남구 신사공원
# 0 0
#
# 643 / 5711  은평구 은평역사한옥박물관
# 2.1 7
#
# 644 / 5711  강남구 써밋갤러리
# 0 0
#
# 645 / 5711  강서구 국제청소년센터
# 0 0
#
# 646 / 5711  동대문구 전곡시장
# 5.0 1
#
# 647 / 5711  광진구 긴고랑공원
# 5.0 1
#
# 648 / 5711  강동구 브이센터
# 4.4 5
#
# 649 / 5711  종로구 충신시장
# 0 0
#
# 650 / 5711  마포구 한국영상자료원
# 4.6 18
#
# 651 / 5711  중구 이화여고100주년기념관
# 5.0 2
#
# 652 / 5711  강서구 양천향교
# 4.0 6
#
# 653 / 5711  강북구 장미원시장
# 5.0 1
#
# 654 / 5711  서초구 헌인가구단지
# 1.0 2
#
# 655 / 5711  송파구 송파구자원순환공원
# 2.3 3
#
# 656 / 5711  종로구 동대문종합시장D동
# 1.0 1
#
# 657 / 5711  송파구 송파나루공원동호
# 2.0 3
#
# 658 / 5711  관악구 호림박물관
# 5.0 4
#
# 659 / 5711  마포구 메가박스홍대
# 3.5 24
#
# 660 / 5711  송파구 풍납전통시장
# 0 0
#
# 661 / 5711  서초구 SCC홀서초
# 0 0
#
# 662 / 5711  강남구 예림당아트홀
# 0 0
#
# 663 / 5711  동대문구 이경시장
# 4.7 3
#
# 664 / 5711  강동구 천호자전거거리
# 5.0 1
#
# 665 / 5711  마포구 CGV연남
# 3.9 25
#
# 666 / 5711  영등포구 씨랄라워터파크
# 3.2 6
#
# 667 / 5711  마포구 아현시장
# 3.3 7
#
# 668 / 5711  마포구 DMC홍보관
# 2.5 2
#
# 669 / 5711  서초구 잠원쇼핑센터
# 0 0
#
# 670 / 5711  은평구 진관사계곡
# 4.6 5
#
# 671 / 5711  구로구 고척근린시장
# 5.0 1
#
# 672 / 5711  광진구 하이웨이마트구의점
# 1.3 12
#
# 673 / 5711  은평구 범서쇼핑센터
# 0 0
#
# 674 / 5711  광진구 노룬산골목시장
# 4.6 5
#
# 675 / 5711  관악구 관음사
# 4.0 4
#
# 676 / 5711  관악구 봉천중앙시장
# 3.7 3
#
# 677 / 5711  중구 CGV명동역씨네라이브러리
# 3.6 28
#
# 678 / 5711  중구 세븐럭강북힐튼점
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 679 / 5711  동대문구 청량리수산시장
# 2.6 5
#
# 680 / 5711  송파구 중앙청과
# 0 0
#
# 681 / 5711  종로구 동덕여자대학교공연예술센터
# 5.0 3
#
# 682 / 5711  은평구 서울기록원
# 4.5 2
#
# 683 / 5711  종로구 티오엠
# 1.0 2
#
# 684 / 5711  서초구 모차르트홀
# 4.0 2
#
# 685 / 5711  마포구 쁘띠몽드마포중앙도서관점
# 4.0 5
#
# ...
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 1945 / 5711  강동구 새장터어린이공원
# 5.0 1
#
# 1946 / 5711  종로구 JJ중정갤러리
# 0 0
#
# 1947 / 5711  서대문구 아트하우스모모
# 4.4 11
#
# 1948 / 5711  송파구 한강시민공원야구장
# 0 0
#
# 1949 / 5711  서초구 잠원한강공원눈썰매장
# 0 0
#
# 1950 / 5711  종로구 동아일보사옥
# 4.0 5
#
# 1951 / 5711  중구 한국금융사박물관
# 4.7 3
#
# 1952 / 5711  은평구 마린크루
# 3.0 4
#
# 1953 / 5711  동작구 지덕사부묘소
# 3.7 3
#
# 1954 / 5711  중구 NH아트홀
# 0 0
#
# 1955 / 5711  종로구 한벽원미술관
# 0 0
#
# 1956 / 5711  동대문구 깡통시장
# 5.0 1
#
# 1957 / 5711  종로구 한미사진미술관별관
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 1958 / 5711  서초구 도잉아트
# 0 0
#
# 1959 / 5711  종로구 한양레퍼토리
# 0 0
#
# 1960 / 5711  금천구 사조씨푸드구로지점
# 0 0
#
# 1961 / 5711  강남구 이유진갤러리
# 5.0 1
#
# 1962 / 5711  관악구 밀가루랑키즈카페
# 5.0 5
#
# 1963 / 5711  금천구 삼성체육공원
# 0 0
#
# 1964 / 5711  관악구 퐁퐁플라워관악센터
# 3.4 11
#
# 1965 / 5711  종로구 안똔체홉극장
# 4.0 2
#
# 1966 / 5711  서초구 슈팅스타사격장
# 5.0 2
#
# 1967 / 5711  서초구 채빛섬
# 3.0 2
#
# 1968 / 5711  종로구 SlowStayDa
# 3.0 2
#
# 1969 / 5711  강남구 덕암사
# 5.0 2
#
# 1970 / 5711  중구 하늘극장
# 0 0
#
# 1971 / 5711  강남구 개포4복합문화센터건축중(2022년03 완공예정)
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 1972 / 5711  마포구 탈영역우정국
# 5.0 6
#
# 1973 / 5711  마포구 가온문화공원
# 5.0 1
#
# 1974 / 5711  종로구 에이라운지갤러리
# 1.0 1
#
# 1975 / 5711  구로구 화원상상어린이공원
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 1976 / 5711  종로구 시온아트홀
# 0 0
#
# 1977 / 5711  광진구 리틀엔젤스예술회관
# 3.5 11
#
# 1978 / 5711  종로구 대학로스타시티
# 0 0
#
# 1979 / 5711  마포구 만리재
# 5.0 1
#
# 1980 / 5711  송파구 올림픽공원만남의광장
# 0 0
#
# 1981 / 5711  종로구 업스테이지
# 0 0
#
# 1982 / 5711  마포구 만리배수지공원
# 5.0 1
#
# 1983 / 5711  강북구 방천시장
# 3.0 1
#
# 1984 / 5711  강서구 서남물재생센터공원파크골프장
# 0 0
#
# 1985 / 5711  용산구 서울정원박람회(해방촌)
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 1986 / 5711  강남구 키즈카페하이아이
# 5.0 1
#
# 1987 / 5711  송파구 상상공방도자기
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 1988 / 5711  용산구 서울역도심공항터미널
# 3.0 1
#
# 1989 / 5711  종로구 예술청
# 5.0 2
#
# 1990 / 5711  종로구 미마지아트센터눈빛극장
# 5.0 1
#
# 1991 / 5711  종로구 표갤러리
# 0 0
#
# 1992 / 5711  종로구 판씨네마
# 0 0
#
# 1993 / 5711  서초구 J&R아트홀
# 5.0 3
#
# 1994 / 5711  성북구 만해한용운심우장
# 4.2 12
#
# 1995 / 5711  종로구 댕로홀
# 5.0 4
#
# 1996 / 5711  종로구 북극곰소극장
# 5.0 2
#
# 1997 / 5711  은평구 북한산둘레길9구간
# 4.6 5
#
# 1998 / 5711  도봉구 초안산생태공원
# 5.0 4
#
# 1999 / 5711  강남구 리나갤러리
# 0 0
#
# 2000 / 5711  광진구 뚝섬한강공원축구장
# 0 0
#
# 2001 / 5711  마포구 불리스튜디오
# 0 0
#
# 2002 / 5711  은평구 다문화박물관
# 2.3 3
#
# 2003 / 5711  강남구 은행나무공원
# 0 0
#
# 2004 / 5711  구로구 노리파크대베가랜드구로점
# 2.8 4
#
# 2005 / 5711  노원구 하계어울림센터
# 5.0 3
#
# 2006 / 5711  강남구 선릉아트홀
# 5.0 1
#
# 2007 / 5711  용산구 뉴스프링프로젝트
# 5.0 1
#
# 2008 / 5711  마포구 온수공간
# 5.0 2
#
# 2009 / 5711  성북구 서울예술치유허브
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 2010 / 5711  서초구 일성갤러리
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 2011 / 5711  종로구 갤러리밈
# 0 0
#
# 2012 / 5711  서대문구 스페이스독
# 4.0 16
#
# 2013 / 5711  양천구 오솔길근린공원
# 0 0
#
# 2014 / 5711  은평구 삼보사
# 0 0
#
# 2015 / 5711  성북구 LKATEGallery
# 정보 없음
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]"}
#   (Session info: chrome=111.0.5563.65)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FADCE3]
# 	(No symbol) [0x00F439D1]
# 	(No symbol) [0x00E54DA8]
# 	(No symbol) [0x00E8019F]
# 	(No symbol) [0x00E803AB]
# 	(No symbol) [0x00EAEE62]
# 	(No symbol) [0x00E9AF14]
# 	(No symbol) [0x00EAD57C]
# 	(No symbol) [0x00E9ACC6]
# 	(No symbol) [0x00E76F68]
# 	(No symbol) [0x00E780CD]
# 	GetHandleVerifier [0x01223832+2506274]
# 	GetHandleVerifier [0x01259794+2727300]
# 	GetHandleVerifier [0x0125E36C+2746716]
# 	GetHandleVerifier [0x01056690+617600]
# 	(No symbol) [0x00F4C712]
# 	(No symbol) [0x00F51FF8]
# 	(No symbol) [0x00F520DB]
# 	(No symbol) [0x00F5C63B]
# 	BaseThreadInitThunk [0x753000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77487BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77487B8E+238]
#
#
# 2016 / 5711  마포구 브라운사운드
# 3.0 1
#
# 2017 / 5711  성북구 선잠단지
# 2.0 2
#
# 2018 / 5711  강남구 대진공원
# 5.0 3
#
# 2019 / 5711  마포구 하늘공원메타세콰이어길
# 4.5 6
#
# 2020 / 5711  용산구 BHAK
# 5.0 1
#
# 2021 / 5711  금천구 모닝푸드
# 0 0
#
# 2022 / 5711  마포구 양화진역사공원
# 4.3 4
#
# 2023 / 5711  중구 투움아트홀
# 5.0 1
#
# 2024 / 5711  강남구 아트컨티뉴
# 3.5 2
#
# 2025 / 5711  광진구 햇님어린이공원
# 5.0 4
#
# 2026 / 5711  성북구 삼선포교원
# 0 0
#
# 2027 / 5711  관악구 원당종합시장
# 5.0 1
#
# 2028 / 5711  영등포구 선유도안내센터
# 0 0
#
# 2029 / 5711  마포구 성미약수터
# 0 0
#
# 2030 / 5711  관악구 관악산생태공원
# 4.3 3
#
# 2031 / 5711  노원구 바운스트램폴린파크월계이마트센터
# 4.0 6
#
# 2032 / 5711  노원구 기원사
# 0 0
#
# 2033 / 5711  서초구 아이노스아트홀
# 0 0
#
# 2034 / 5711  종로구 굿씨어터
# 4.0 1
#
# 2035 / 5711  강남구 압구정토끼굴
# 4.4 30
#
# 2036 / 5711  성북구 홍련사
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3668\2654524425.py in <module>
#      52         driver.implicitly_wait(time_to_wait=10)
#      53
# ---> 54         newlink = driver.find_element(by='xpath',value = '//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').send_keys(Keys.ENTER)
#      55
#      56         driver.switch_to.window(driver.window_handles[-1])
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
#     829
# --> 830         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     831
#     832     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     436                 params["sessionId"] = self.session_id
#     437
# --> 438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
#     440             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     288         data = utils.dump_json(params)
#     289         url = f"{self._url}{path}"
# --> 290         return self._request(command_info[0], url, body=data)
#     291
#     292     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     309
#     310         if self.keep_alive:
# --> 311             response = self._conn.request(method, url, body=body, headers=headers)
#     312             statuscode = response.status
#     313         else:
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
arr_data[:100]

# %%
t1 = list(tmp.split("\n"))

t1[153]
# Out:
# 'Backtrace:'

# %%
data = []

i = 0
while i < len(t1)-2:
    now = t1[i]
#     print(f'{i+1}번째 값 : {now}')
    if '/' in now and 'Message' not in now:
#         print(f'now 값 {now}')
        next = t1[i+1]
#         print(now.split('/')[0].split(" ")[0])
        if next == '정보 없음':
            data.append(('0','0'))
            i += 1
            while '/' not in t1[i]  and 'Message' not in now:
                i += 1
            i -= 1
        else: # 정보 있음
            sp = next.split(' ')
            rating = float(sp[0])
            review = int(sp[1])
            data.append((rating, review))
        
    i += 1
        
# for i in range(len(data)):
#     print(f'{i+1}.  {data[i]}')
    
print(data[0])
# Out:
# (3.8, 143)

# %%
import openpyxl
import os
import sys
import time
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    return driver

filename = './data/res_seoul.xlsx'
spot_file = openpyxl.load_workbook(filename)
spots = spot_file.worksheets[0]



data = []

for spot in spots.iter_rows(min_row=2):
    
    name = spot[0].value
    gu = spot[1].value
    address = spot[2].value
    
    if address is not None:
        data.append([gu,name])

data = data[2035:5705]

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = set_chrome_driver()

arr_data = []
idx = 2035
for i in data:
    print(f'{idx} / 5711 ',end=" ")
    idx += 1
    keyword = i[0] + ' ' + i[1]
    print(keyword)
    try:
        
        # 검색
        kakao_map_search_url = f"https://map.kakao.com/?q={keyword}"
        driver.get(kakao_map_search_url)
        driver.implicitly_wait(time_to_wait=10)

        newlink = driver.find_element(by='xpath',value = '//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').send_keys(Keys.ENTER)
        
        driver.switch_to.window(driver.window_handles[-1])

        res = list(driver.find_element(by='xpath',value = '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]').text.split(' ')[1].split('\n'))
        
        num_rate = res[0]
        review_cnt = res[1][1:-1]
        print(num_rate, review_cnt)
                
        arr_data.append((num_rate, review_cnt))
            
        driver.close()
        driver.switch_to.window(driver.window_handles[0]);

    except Exception as e1:
        print("정보 없음")
        arr_data.append(('0', '0'))
        driver.switch_to.window(driver.window_handles[0]);


sheet = spot_file['Sheet1']
# 컬럼 추가
# sheet.insert_cols(7)
# sheet.insert_cols(8)
sheet.cell(row=1, column=7, value='rating') # 새로운 컬럼의 헤더 추가
sheet.cell(row=1, column=8, value='reviews') # 새로운 컬럼의 헤더 추가
    
    

# spot_file.save("./data/ExcelToCSV.xlsx")



for i, item in enumerate(arr_data, start=2035): # 2번째 행부터 데이터 추가
    rate, review = item
    sheet.cell(row=i, column=7, value=rate)
    sheet.cell(row=i, column=8, value=review)
    
    
spot_file.save("./data/res_res_seoul.xlsx")
driver.close()
print("완료!")
# Out:
# 2035 / 5711  성북구 홍련사
# 정보 없음
# 2036 / 5711  강남구 ADM커뮤니티갤러리
# 정보 없음
# 2037 / 5711  서초구 고투몰
# 3.3 7
# 2038 / 5711  종로구 세종이야기
# 4.8 9
# 2039 / 5711  중구 로컬스티치소공점
# 정보 없음
# 2040 / 5711  관악구 관악산호수공원
# 1.0 1
# 2041 / 5711  성동구 갤러리구조
# 4.0 1
# 2042 / 5711  동작구 청원민물고기직판장
# 정보 없음
# 2043 / 5711  마포구 드림홀
# 5.0 1
# 2044 / 5711  은평구 심택사
# 5.0 1
# 2045 / 5711  종로구 R&J씨어터
# 0 0
# 2046 / 5711  종로구 일백헌
# 0 0
# 2047 / 5711  관악구 미성동도깨비시장
# 4.0 1
# 2048 / 5711  서대문구 대종교총본사
# 5.0 2
# 2049 / 5711  강남구 넵튠수상스키장압구정점
# 5.0 1
# 2050 / 5711  강동구 성심어린이공원
# 0 0
# 2051 / 5711  관악구 예촌어린이공원
# 0 0
# 2052 / 5711  강서구 김포공항전망대
# 4.3 6
# 2053 / 5711  강남구 갤러리두
# 0 0
# 2054 / 5711  마포구 트랜지션정글
# 5.0 1
# 2055 / 5711  영등포구 선유도공원작은식물원
# 정보 없음
# 2056 / 5711  서초구 국립국악원연희풍류극장
# 정보 없음
# 2057 / 5711  중구 로컬스티치약수
# 4.0 2
# 2058 / 5711  종로구 에이치씨어터
# 5.0 2
# 2059 / 5711  강북구 으뜸어린이공원
# 0 0
# 2060 / 5711  노원구 화랑대역폐역
# 5.0 16
# 2061 / 5711  마포구 극동방송아트홀
# 0 0
# 2062 / 5711  종로구 소극장혜화당
# 4.0 1
# 2063 / 5711  송파구 래미안파크팰리스상가
# 0 0
# 2064 / 5711  강남구 김리아갤러리
# 5.0 11
# 2065 / 5711  종로구 정수아트센터
# 5.0 3
# 2066 / 5711  서초구 가빛섬
# 4.0 3
# 2067 / 5711  마포구 상암마린랜드
# 0 0
# 2068 / 5711  관악구 새들어린이공원
# 0 0
# 2069 / 5711  영등포구 도림유수지
# 0 0
# 2070 / 5711  종로구 경교장
# 4.8 44
# 2071 / 5711  광진구 더키즈프리미엄키즈카페
# 4.0 1
# 2072 / 5711  성북구 노리파크길음점
# 0 0
# 2073 / 5711  용산구 전쟁기념관어린이날문화축제
# 정보 없음
# 2074 / 5711  종로구 아루또소극장
# 4.3 4
# 2075 / 5711  종로구 홍화문
# 4.8 5
# 2076 / 5711  동대문구 HM풋살파크동대문점
# 4.0 1
# 2077 / 5711  종로구 PUESTO
# 정보 없음
# 2078 / 5711  중구 신아기념관
# 0 0
# 2079 / 5711  강남구 VSG아레나
# 0 0
# 2080 / 5711  관악구 삼성산청소년수련원
# 2.0 1
# 2081 / 5711  동대문구 경동광성상가

# %%
import openpyxl
import os
import sys
import time
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


filename = './data/seoul.xlsx'
spot_file = openpyxl.load_workbook(filename)
spots = spot_file.worksheets[0]


sheet = spot_file['Sheet1']
# 컬럼 추가
sheet.insert_cols(7)
sheet.insert_cols(8)
sheet.cell(row=1, column=7, value='rating') # 새로운 컬럼의 헤더 추가
sheet.cell(row=1, column=8, value='reviews') # 새로운 컬럼의 헤더 추가
    

for i, item in enumerate(data, start=2): # 2번째 행부터 데이터 추가
    rate, review = item
    sheet.cell(row=i, column=7, value=rate)
    sheet.cell(row=i, column=8, value=review)
    
    
spot_file.save("./data/res_seoul.xlsx")
print("완료!")
# Out:
# 완료!
