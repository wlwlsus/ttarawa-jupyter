# %%
# !pip install selenium

# %%
# !pip install webdriver-manager

# %%
import openpyxl
import os
import sys
import time
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    return driver

filename = './data/seoul.xlsx'
spot_file = openpyxl.load_workbook(filename)
spots = spot_file.worksheets[0]



data = []

for spot in spots.iter_rows(min_row=2):
    
    name = spot[0].value
    gu = spot[1].value
    address = spot[2].value
    
    if address is not None:
        data.append([gu,name])


options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = set_chrome_driver()

arr_data = []
idx = 1
for i in data:
    print(f'{idx} / 5711 ',end=" ")
    idx += 1
    keyword = i[0] + ' ' + i[1]
    print(keyword)
    try:
        
        # 검색
        kakao_map_search_url = f"https://map.kakao.com/?q={keyword}"
        driver.get(kakao_map_search_url)
        driver.implicitly_wait(time_to_wait=10)

        newlink = driver.find_element(by='xpath',value = '//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').send_keys(Keys.ENTER)
        
        driver.switch_to.window(driver.window_handles[-1])

        res = list(driver.find_element(by='xpath',value = '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]').text.split(' ')[1].split('\n'))
        
        num_rate = res[0]
        review_cnt = res[1][1:-1]
        print(num_rate, review_cnt)
                
        arr_data.append((num_rate, review_cnt))
            
        driver.close()
        driver.switch_to.window(driver.window_handles[0]);

    except Exception as e1:
        print("정보 없음")
        print(e1)
        driver.switch_to.window(driver.window_handles[0]);
        pass

    print()

sheet = spot_file['Sheet1']
# 컬럼 추가
sheet.insert_cols(7)
sheet.insert_cols(8)
sheet.cell(row=1, column=7, value='rating') # 새로운 컬럼의 헤더 추가
sheet.cell(row=1, column=8, value='reviews') # 새로운 컬럼의 헤더 추가
    
    

# spot_file.save("./data/ExcelToCSV.xlsx")



for i, item in enumerate(arr_data, start=2): # 2번째 행부터 데이터 추가
    rate, review = item
    sheet.cell(row=i, column=7, value=rate)
    sheet.cell(row=i, column=8, value=review)
    
    
spot_file.save("./data/res_seoul.xlsx")
driver.close()
print("완료!")

# %%
arr_data[:100]

# %%
t1 = list(tmp.split("\n"))

t1

# %%
data = []

i = 0
while i < len(t1)-3:
    now = t1[i]
#     print(f'{i+1}번째 값 : {now}')
    if '/' in now and 'Message' not in now:
#         print(f'now 값 {now}')
        next = t1[i+1]
#         print(now.split('/')[0].split(" ")[0])
        if next == '정보 없음':
            data.append((0.0,0))
            i += 1
            while '/' not in t1[i]  and 'Message' not in now:
                i += 1
            i -= 1
        else: # 정보 있음
            sp = next.split(' ')
            rating = float(sp[0])
            review = int(sp[1])
            data.append((rating, review))
        
    i += 1
        
for i in range(len(data)):
    print(f'{i+1}.  {data[i]}')
    
print(data[0])

# %%
import openpyxl
import os
import sys
import time
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    return driver

filename = './data/res_seoul.xlsx'
spot_file = openpyxl.load_workbook(filename)
spots = spot_file.worksheets[0]



data = []

for spot in spots.iter_rows(min_row=2):
    
    name = spot[0].value
    gu = spot[1].value
    address = spot[2].value
    
    if address is not None:
        data.append([gu,name])

data = data[5168:]

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = set_chrome_driver()

arr_data = []
idx = 5168
for i in data:
    print(f'{idx} / 5711 ',end=" ")
    idx += 1
    keyword = i[0] + ' ' + i[1]
    print(keyword)
    try:
        
        # 검색
        kakao_map_search_url = f"https://map.kakao.com/?q={keyword}"
        driver.get(kakao_map_search_url)
        driver.implicitly_wait(time_to_wait=10)

        newlink = driver.find_element(by='xpath',value = '//*[@id="info.search.place.list"]/li[1]/div[5]/div[4]/a[1]').send_keys(Keys.ENTER)
        
        driver.switch_to.window(driver.window_handles[-1])

        res = list(driver.find_element(by='xpath',value = '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]').text.split(' ')[1].split('\n'))
        
        num_rate = res[0]
        review_cnt = res[1][1:-1]
        print(num_rate, review_cnt)
                
        arr_data.append((num_rate, review_cnt))
            
        driver.close()
        driver.switch_to.window(driver.window_handles[0]);

    except Exception as e1:
        print("정보 없음")
        arr_data.append((0.0, 0))
        driver.switch_to.window(driver.window_handles[0]);


sheet = spot_file['Sheet1']
# 컬럼 추가
# sheet.insert_cols(7)
# sheet.insert_cols(8)
# sheet.cell(row=1, column=7, value='rating') # 새로운 컬럼의 헤더 추가
# sheet.cell(row=1, column=8, value='reviews') # 새로운 컬럼의 헤더 추가
    
    

# spot_file.save("./data/ExcelToCSV.xlsx")



for i, item in enumerate(arr_data, start=5170): # 2번째 행부터 데이터 추가
    rate, review = item
    sheet.cell(row=i, column=7, value=rate)
    sheet.cell(row=i, column=8, value=review)
    
    
spot_file.save("./data/res_res_seoul.xlsx")
driver.close()
print("완료!")

# %%
data

# %%
import openpyxl
import os
import sys
import time
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


filename = './data/res_seoul.xlsx'
spot_file = openpyxl.load_workbook(filename)
spots = spot_file.worksheets[0]


sheet = spot_file['Sheet1']
# 컬럼 추가
# sheet.insert_cols(7)
# sheet.insert_cols(8)
# sheet.cell(row=1, column=7, value='rating') # 새로운 컬럼의 헤더 추가
# sheet.cell(row=1, column=8, value='reviews') # 새로운 컬럼의 헤더 추가
    

for i, item in enumerate(data, start=2037): # 2번째 행부터 데이터 추가
    rate, review = item
    sheet.cell(row=i, column=7, value=rate)
    sheet.cell(row=i, column=8, value=review)
    
    
spot_file.save("./data/res_res_seoul.xlsx")
print("완료!")
